# %%
import pandas as pd

# %%
# Loading the API-collected dataset from GitHub
url = "https://raw.githubusercontent.com/pakizaim7/spacex-capstone/main/notebooks/spacex_launch_data_api.csv"

df = pd.read_csv(url)

df.head()
# Out:
#    flight_number         name                   date_utc success  \
# 0              1    FalconSat  2006-03-24 22:30:00+00:00   False
# 1              2      DemoSat  2007-03-21 01:10:00+00:00   False
# 2              3  Trailblazer  2008-08-03 03:34:00+00:00   False
# 3              4       RatSat  2008-09-28 23:15:00+00:00    True
# 4              5     RazakSat  2009-07-13 03:35:00+00:00    True
#
#                      rocket  \
# 0  5e9d0d95eda69955f709d1eb
# 1  5e9d0d95eda69955f709d1eb
# 2  5e9d0d95eda69955f709d1eb
# 3  5e9d0d95eda69955f709d1eb
# 4  5e9d0d95eda69955f709d1eb
#
#                                             payloads  \
# 0                       ['5eb0e4b5b6c3bb0006eeb1e1']
# 1                       ['5eb0e4b6b6c3bb0006eeb1e2']
# 2  ['5eb0e4b6b6c3bb0006eeb1e3', '5eb0e4b6b6c3bb00...
# 3                       ['5eb0e4b7b6c3bb0006eeb1e5']
# 4                       ['5eb0e4b7b6c3bb0006eeb1e6']
#
#                   launchpad  launch_year  class
# ...

# %% [markdown]
# """
# Web Scraping Methodology (Conceptual Explanation):
#
# 1. Identify a public data source (Wikipedia Falcon 9 launch history page)
# 2. Send an HTTP request to retrieve the web page content
# 3. Parse HTML using BeautifulSoup
# 4. Locate launch-related tables (payload mass, orbit, booster version)
# 5. Extract relevant columns and convert them into a pandas DataFrame
# 6. Clean and standardize the extracted data
#
# Limitation:
# Due to HTTP 403 access restrictions and frequent changes in page structure,
# automated scraping was not consistently accessible in the notebook environment.
# To ensure reproducibility and data consistency, the cleaned dataset was saved
# as a CSV file and reused throughout the project.
# """

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   flight_number  187 non-null    int64
#  1   name           187 non-null    object
#  2   date_utc       187 non-null    object
#  3   success        186 non-null    object
#  4   rocket         187 non-null    object
#  5   payloads       187 non-null    object
#  6   launchpad      187 non-null    object
#  7   launch_year    187 non-null    int64
#  8   class          187 non-null    int64
# dtypes: int64(3), object(6)
# memory usage: 13.3+ KB

# %%
df.to_csv("spacex_launch_data_web_scraping.csv", index=False)

print("Local CSV copy saved.")
# Out:
# Local CSV copy saved.

# %%
df.shape
# Out:
# (187, 9)
